# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('train.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
a=data.corr().index

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data[a].corr(),annot=True)

# %%
data.drop(['talk_time'],axis=1,inplace=True)

# %%
X=data.iloc[:,:-1]
y=data['price_range']

# %%
print(X.shape,y.shape)
# Out:
# (2000, 19) (2000,)

# %%
X.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'three_g', 'touch_screen', 'wifi'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
from sklearn.ensemble import ExtraTreesClassifier
cls=ExtraTreesClassifier()
cls.fit(X_train,y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
imp=cls.feature_importances_

# %%
b=pd.Series(imp,index=X.columns)
b.nlargest(10).plot(kind='barh')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(X_train,y_train)
lin.score(X_test,y_test)
# Out:
# 0.9192909689435536

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier(n_neighbors=7)
kn.fit(X_train,y_train)
kn.score(X_test,y_test)
# Out:
# 0.946

# %%
from sklearn.tree import DecisionTreeClassifier
ctree=DecisionTreeClassifier(max_depth=7)
ctree.fit(X_train,y_train)
ctree.score(X_test,y_test)
# Out:
# 0.812

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier(n_estimators=400,max_depth=7)
ran.fit(X_train,y_train)
ran.score(X_test,y_test)
# Out:
# 0.862

# %%
kn.predict(X_test)
# Out:
# array([0, 2, 1, 3, 1, 1, 2, 0, 3, 1, 0, 1, 2, 3, 2, 2, 3, 3, 1, 0, 0, 1,
#        1, 2, 0, 1, 3, 2, 2, 0, 0, 0, 3, 0, 1, 1, 2, 0, 3, 0, 2, 3, 2, 0,
#        2, 2, 2, 1, 3, 1, 3, 1, 0, 0, 0, 0, 1, 3, 0, 0, 1, 3, 3, 1, 0, 0,
#        3, 3, 1, 2, 2, 2, 0, 1, 2, 0, 0, 3, 2, 2, 3, 2, 1, 0, 1, 3, 1, 3,
#        3, 0, 3, 3, 2, 1, 3, 2, 2, 3, 1, 1, 0, 0, 1, 0, 0, 3, 2, 0, 1, 1,
#        0, 0, 3, 1, 3, 2, 3, 2, 0, 2, 1, 3, 2, 1, 3, 3, 0, 2, 0, 2, 3, 0,
#        2, 2, 0, 3, 1, 0, 0, 2, 2, 1, 3, 2, 0, 0, 0, 1, 1, 2, 3, 1, 1, 0,
#        2, 2, 0, 1, 0, 2, 2, 3, 3, 2, 1, 0, 1, 2, 2, 3, 3, 0, 1, 0, 3, 1,
#        1, 2, 1, 0, 0, 0, 0, 0, 3, 2, 0, 3, 0, 0, 0, 0, 1, 3, 3, 1, 0, 1,
#        1, 1, 1, 2, 2, 2, 3, 3, 1, 2, 0, 0, 0, 2, 1, 1, 3, 1, 0, 2, 1, 1,
#        3, 2, 3, 0, 0, 2, 1, 3, 0, 1, 2, 0, 2, 3, 2, 0, 1, 3, 3, 0, 1, 3,
#        2, 3, 0, 3, 1, 2, 3, 3, 2, 1, 0, 3, 3, 1, 3, 3, 3, 3, 3, 0, 1, 2,
#        2, 1, 3, 0, 1, 3, 2, 2, 2, 1, 0, 1, 0, 3, 3, 1, 3, 1, 0, 3, 1, 2,
# ...

# %%
y_pred=kn.predict(X_test)

# %%
plt.plot(y_test,y_pred)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.96      0.97      0.97       132\n           1       0.90      0.95      0.92       118\n           2       0.94      0.91      0.92       120\n           3       0.98      0.95      0.97       130\n\n    accuracy                           0.95       500\n   macro avg       0.95      0.95      0.95       500\nweighted avg       0.95      0.95      0.95       500\n'

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.946

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[128,   4,   0,   0],
#        [  5, 112,   1,   0],
#        [  0,   9, 109,   2],
#        [  0,   0,   6, 124]], dtype=int64)

# %%
import pickle

# %%
file=open('phone_.pkl','wb')
pickle.dump(kn,file)

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  three_g  \
# 0        188        2   2         20       756  2549     9     7        0
# 1        136        3   6        905      1988  2631    17     3        1
# 2        145        5   6       1263      1716  2603    11     2        1
# 3        131        6   9       1216      1786  2769    16     8        1
# 4        141        2  14       1208      1212  1411     8     2        1
#
#    touch_screen  wifi
# 0             0     1
# ...
